# %% [markdown]
# <a href="https://colab.research.google.com/github/marceloadade/FIAP_POS_TECH_DTAT/blob/main/Aula3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd;

# %%
dados = pd.read_csv("/content/sih_cnv_qiuf121520189_28_148_82.csv",encoding="ISO-8859-1",skiprows=3,sep=";",skipfooter=12,decimal=",",thousands=".",engine='python',header=0);

# %%
dados.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan 1994/Fev  \
# 0          11 Rondônia        -        -        -        -        -        -
# 1              12 Acre        -        -        -        -        -        -
# 2          13 Amazonas        -        -        -        -        -        -
# 3           14 Roraima        -        -        -        -        -        -
# 4              15 Pará        -        -        -        -        -        -
#
#   1994/Mai 1994/Ago 1994/Nov  ...     2023/Nov     2023/Dez     2024/Jan  \
# 0        -        -        -  ...  12651707.83  11943923.52  11711724.10
# 1        -        -        -  ...   4436469.66   4253339.65   4404809.58
# 2        -        -        -  ...  19232896.85  18603854.01  21742871.19
# 3        -        -        -  ...   2950886.84   3274540.99   3032721.61
# 4        -        -        -  ...  58381194.67  50786654.84  52681476.65
#
# ...

# %%
dados.tail()
# Out:
#      Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan  \
# 22   43 Rio Grande do Sul        -        -        -        -        -
# 23  50 Mato Grosso do Sul        -        -        -        -        -
# 24         51 Mato Grosso        -        -        -        -        -
# 25               52 Goiás        -        -        -        -        -
# 26    53 Distrito Federal        -        -        -        -        -
#
#    1994/Fev 1994/Mai 1994/Ago 1994/Nov  ...      2023/Nov      2023/Dez  \
# 22        -        -        -        -  ...  1.165616e+08  1.116972e+08
# 23        -        -        -        -  ...  2.662279e+07  2.558690e+07
# 24        -        -        -        -  ...  2.343550e+07  2.224564e+07
# 25        -        -        -        -  ...  5.168061e+07  4.774622e+07
# 26        -        -        -        -  ...  3.033361e+07  2.849657e+07
#
#         2024/Jan      2024/Fev      2024/Mar      2024/Abr     2024/Mai  \
# ...

# %%
dados[['2008/Ago','2008/Set']].head()
# Out:
#       2008/Ago     2008/Set
# 0   2938286.29   2843930.91
# 1   1886871.84   2084884.80
# 2   8331763.97   8148089.92
# 3   1045291.11   1003740.89
# 4  23259148.28  23667690.01

# %%
dados.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan 1994/Fev  \
# 0          11 Rondônia        -        -        -        -        -        -
# 1              12 Acre        -        -        -        -        -        -
# 2          13 Amazonas        -        -        -        -        -        -
# 3           14 Roraima        -        -        -        -        -        -
# 4              15 Pará        -        -        -        -        -        -
#
#   1994/Mai 1994/Ago 1994/Nov  ...     2023/Nov     2023/Dez     2024/Jan  \
# 0        -        -        -  ...  12651707.83  11943923.52  11711724.10
# 1        -        -        -  ...   4436469.66   4253339.65   4404809.58
# 2        -        -        -  ...  19232896.85  18603854.01  21742871.19
# 3        -        -        -  ...   2950886.84   3274540.99   3032721.61
# 4        -        -        -  ...  58381194.67  50786654.84  52681476.65
#
# ...

# %%
dados.columns
# Out:
# Index(['Unidade da Federação', '1992/Mar', '1992/Abr', '1993/Mai', '1993/Dez',
#        '1994/Jan', '1994/Fev', '1994/Mai', '1994/Ago', '1994/Nov',
#        ...
#        '2023/Nov', '2023/Dez', '2024/Jan', '2024/Fev', '2024/Mar', '2024/Abr',
#        '2024/Mai', '2024/Jun', '2024/Jul', 'Total'],
#       dtype='object', length=327)

# %%
dados.mean(numeric_only = True)
# Out:
# 2007/Ago    3.049528e+05
# 2007/Set    7.881453e+05
# 2007/Out    2.440163e+06
# 2007/Nov    5.517354e+06
# 2007/Dez    1.233716e+07
#                 ...
# 2024/Mar    7.074535e+07
# 2024/Abr    7.206920e+07
# 2024/Mai    6.589635e+07
# 2024/Jun    5.280992e+07
# Total       9.009900e+09
# Length: 204, dtype: float64

# %%
dados.mean(numeric_only = True).index.tolist()
# Out:
# ['2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
#  '2012/Dez',
#  '2013/Jan',
# ...

# %%
colunas_usaveis = dados.mean(numeric_only = True).index.tolist()
colunas_usaveis.insert(0,"Unidade da Federação")
colunas_usaveis[:5]
# Out:
# ['Unidade da Federação', '2007/Ago', '2007/Set', '2007/Out', '2007/Nov']

# %%
dados_usaveis = dados[colunas_usaveis]
dados_usaveis.head()
# Out:
#   Unidade da Federação   2007/Ago   2007/Set    2007/Out    2007/Nov  \
# 0          11 Rondônia    4209.37   16397.03   133645.19   346912.84
# 1              12 Acre   10470.07   14001.71    86200.85   301323.68
# 2          13 Amazonas   35752.72   45570.64   416012.30  2020381.79
# 3           14 Roraima    4785.91   11858.63    43852.67   369328.51
# 4              15 Pará  181159.29  433414.74  1893197.50  5105406.44
#
#       2007/Dez     2008/Jan     2008/Fev     2008/Mar     2008/Abr  ...  \
# 0    711758.31   1829559.71   1940792.63   1955721.68   2143353.81  ...
# 1    769612.36   1731744.62   1743978.66   2057439.02   2057829.69  ...
# 2   5949408.99  11419210.08   7934652.10   8641517.13   8531576.49  ...
# 3    470676.43    808448.39    771687.83    876091.18    896952.53  ...
# 4  13162823.43  21762104.16  20126081.01  22149375.82  23436682.75  ...
#
#       2023/Out     2023/Nov     2023/Dez     2024/Jan     2024/Fev  \
# ...

# %%
dados_usaveis.set_index("Unidade da Federação",inplace=True)
dados_usaveis.head()
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 11 Rondônia             4209.37   16397.03   133645.19   346912.84
# 12 Acre                10470.07   14001.71    86200.85   301323.68
# 13 Amazonas            35752.72   45570.64   416012.30  2020381.79
# 14 Roraima              4785.91   11858.63    43852.67   369328.51
# 15 Pará               181159.29  433414.74  1893197.50  5105406.44
#
#                          2007/Dez     2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 11 Rondônia             711758.31   1829559.71   1940792.63   1955721.68
# 12 Acre                 769612.36   1731744.62   1743978.66   2057439.02
# 13 Amazonas            5949408.99  11419210.08   7934652.10   8641517.13
# 14 Roraima              470676.43    808448.39    771687.83    876091.18
# 15 Pará               13162823.43  21762104.16  20126081.01  22149375.82
#
# ...

# %%
dados_usaveis['2007/Ago']
# Out:
# Unidade da Federação
# 11 Rondônia                  4209.37
# 12 Acre                     10470.07
# 13 Amazonas                 35752.72
# 14 Roraima                   4785.91
# 15 Pará                    181159.29
# 16 Amapá                    33672.74
# 17 Tocantins                 4113.76
# 21 Maranhão                385330.18
# 22 Piauí                   220788.25
# 23 Ceará                   357904.65
# 24 Rio Grande do Norte     134605.36
# 25 Paraíba                  97352.78
# 26 Pernambuco              400640.85
# 27 Alagoas                 104243.75
# 28 Sergipe                  27453.63
# 29 Bahia                   135146.36
# 31 Minas Gerais            971394.37
# 32 Espírito Santo           57408.11
# 33 Rio de Janeiro          469469.34
# 35 São Paulo              1665349.90
# 41 Paraná                  554800.22
# 42 Santa Catarina          693955.05
# 43 Rio Grande do Sul      1049252.33
# 50 Mato Grosso do Sul      199556.12
# 51 Mato Grosso              63562.50
# ...

# %%
dados_usaveis.loc['12 Acre']
# Out:
# 2007/Ago    1.047007e+04
# 2007/Set    1.400171e+04
# 2007/Out    8.620085e+04
# 2007/Nov    3.013237e+05
# 2007/Dez    7.696124e+05
#                 ...
# 2024/Mar    4.764699e+06
# 2024/Abr    4.488757e+06
# 2024/Mai    3.406322e+06
# 2024/Jun    1.574829e+06
# Total       6.154166e+08
# Name: 12 Acre, Length: 204, dtype: float64

# %%
dados_usaveis.iloc[1]
# Out:
# 2007/Ago    1.047007e+04
# 2007/Set    1.400171e+04
# 2007/Out    8.620085e+04
# 2007/Nov    3.013237e+05
# 2007/Dez    7.696124e+05
#                 ...
# 2024/Mar    4.764699e+06
# 2024/Abr    4.488757e+06
# 2024/Mai    3.406322e+06
# 2024/Jun    1.574829e+06
# Total       6.154166e+08
# Name: 12 Acre, Length: 204, dtype: float64

# %%
dados_usaveis.plot(figsize=(12,6))
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %%
dados_usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia    12 Acre  13 Amazonas  14 Roraima  \
# 2007/Ago                  4209.37   10470.07     35752.72     4785.91
# 2007/Set                 16397.03   14001.71     45570.64    11858.63
# 2007/Out                133645.19   86200.85    416012.30    43852.67
# 2007/Nov                346912.84  301323.68   2020381.79   369328.51
# 2007/Dez                711758.31  769612.36   5949408.99   470676.43
#
# Unidade da Federação      15 Pará   16 Amapá  17 Tocantins  21 Maranhão  \
# 2007/Ago                181159.29   33672.74       4113.76    385330.18
# 2007/Set                433414.74  104822.98      76633.06   1018352.93
# 2007/Out               1893197.50  118378.28     343702.61   2277717.78
# 2007/Nov               5105406.44  226661.18    1068685.94   4334468.23
# 2007/Dez              13162823.43  844019.90    3022200.87   8832514.85
#
# Unidade da Federação    22 Piauí     23 Ceará  ...  32 Espírito Santo  \
# ...

# %%
dados_usaveis.T.plot(figsize=(12,6))
# Out:
# <Axes: >

# %%
dados_usaveis.T.tail()
# Out:
# Unidade da Federação   11 Rondônia       12 Acre   13 Amazonas    14 Roraima  \
# 2024/Mar              1.280679e+07  4.764699e+06  2.196353e+07  2.682802e+06
# 2024/Abr              1.209910e+07  4.488757e+06  2.126784e+07  1.806928e+06
# 2024/Mai              9.906805e+06  3.406322e+06  2.138888e+07  1.645962e+05
# 2024/Jun              6.603900e+06  1.574829e+06  1.647106e+07  9.339340e+04
# Total                 1.474028e+09  6.154166e+08  2.750515e+09  4.707843e+08
#
# Unidade da Federação       15 Pará      16 Amapá  17 Tocantins   21 Maranhão  \
# 2024/Mar              5.400834e+07  4.059123e+06  1.004656e+07  4.378403e+07
# 2024/Abr              5.426837e+07  3.731018e+06  1.032837e+07  4.251052e+07
# 2024/Mai              4.641367e+07  3.793605e+06  7.938311e+06  3.769261e+07
# 2024/Jun              3.342318e+07  2.026081e+06  4.467400e+06  2.912964e+07
# Total                 6.643953e+09  4.542447e+08  1.433302e+09  5.509040e+09
#
# ...

# %%
dados_usaveis.drop("Total",axis=1,inplace=True)
dados_usaveis
# Out:
# <ipython-input-168-5f12eeab4112>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_usaveis.drop("Total",axis=1,inplace=True)
#                           2007/Ago    2007/Set     2007/Out     2007/Nov  \
# Unidade da Federação
# 11 Rondônia                4209.37    16397.03    133645.19    346912.84
# 12 Acre                   10470.07    14001.71     86200.85    301323.68
# 13 Amazonas               35752.72    45570.64    416012.30   2020381.79
# 14 Roraima                 4785.91    11858.63     43852.67    369328.51
# 15 Pará                  181159.29   433414.74   1893197.50   5105406.44
# 16 Amapá                  33672.74   104822.98    118378.28    226661.18
# 17 Tocantins               4113.76    76633.06    343702.61   1068685.94
# ...

# %%
dados_usa

# %%
#reposicionar legenda
#retoque
dados_usaveis.T.plot(figsize=(12,6))
# Out:
# <Axes: >

# %% [markdown]
# **Desafios e extras!**
#  Fim da parte 1

# %%
#reposicionar legenda
#retoque
dados_usaveis.T.plot(figsize=(12,6))

# %%
dados_usaveis.head()
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 11 Rondônia             4209.37   16397.03   133645.19   346912.84
# 12 Acre                10470.07   14001.71    86200.85   301323.68
# 13 Amazonas            35752.72   45570.64   416012.30  2020381.79
# 14 Roraima              4785.91   11858.63    43852.67   369328.51
# 15 Pará               181159.29  433414.74  1893197.50  5105406.44
#
#                          2007/Dez     2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 11 Rondônia             711758.31   1829559.71   1940792.63   1955721.68
# 12 Acre                 769612.36   1731744.62   1743978.66   2057439.02
# 13 Amazonas            5949408.99  11419210.08   7934652.10   8641517.13
# 14 Roraima              470676.43    808448.39    771687.83    876091.18
# 15 Pará               13162823.43  21762104.16  20126081.01  22149375.82
#
# ...

# %%
dados_usaveis.T.columns
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins', '21 Maranhão', '22 Piauí', '23 Ceará',
#        '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco', '27 Alagoas',
#        '28 Sergipe', '29 Bahia', '31 Minas Gerais', '32 Espírito Santo',
#        '33 Rio de Janeiro', '35 São Paulo', '41 Paraná', '42 Santa Catarina',
#        '43 Rio Grande do Sul', '50 Mato Grosso do Sul', '51 Mato Grosso',
#        '52 Goiás', '53 Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %%
dados_usaveis.T.columns[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
dados_usaveis[:5]
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 11 Rondônia             4209.37   16397.03   133645.19   346912.84
# 12 Acre                10470.07   14001.71    86200.85   301323.68
# 13 Amazonas            35752.72   45570.64   416012.30  2020381.79
# 14 Roraima              4785.91   11858.63    43852.67   369328.51
# 15 Pará               181159.29  433414.74  1893197.50  5105406.44
#
#                          2007/Dez     2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 11 Rondônia             711758.31   1829559.71   1940792.63   1955721.68
# 12 Acre                 769612.36   1731744.62   1743978.66   2057439.02
# 13 Amazonas            5949408.99  11419210.08   7934652.10   8641517.13
# 14 Roraima              470676.43    808448.39    771687.83    876091.18
# 15 Pará               13162823.43  21762104.16  20126081.01  22149375.82
#
# ...

# %%
dados_usaveis[:7].T.plot(figsize=(12,6))
# Out:
# <Axes: >

# %%
dados_usaveis.sample(n=7)
# Out:
#                          2007/Ago    2007/Set     2007/Out     2007/Nov  \
# Unidade da Federação
# 25 Paraíba               97352.78   368130.43   1002088.64   2149873.40
# 33 Rio de Janeiro       469469.34   921646.57   2994664.57   7250528.08
# 50 Mato Grosso do Sul   199556.12   573675.41   1069816.66   1995899.52
# 17 Tocantins              4113.76    76633.06    343702.61   1068685.94
# 35 São Paulo           1665349.90  4434168.64  14577395.84  35032259.98
# 42 Santa Catarina       693955.05  1092964.12   3562300.82   7578502.38
# 52 Goiás                179395.82   418053.58   1198730.25   2712117.54
#
#                           2007/Dez      2008/Jan      2008/Fev      2008/Mar  \
# Unidade da Federação
# 25 Paraíba              5448177.36  1.659900e+07  1.087159e+07  1.234876e+07
# 33 Rio de Janeiro      13627123.27  2.534380e+08  4.412816e+07  4.293377e+07
# 50 Mato Grosso do Sul   4277979.14  8.301006e+06  8.279289e+06  9.793889e+06
# ...

# %%
dados_usaveis.sample(7).T.plot(figsize=(12,6))
# Out:
# <Axes: >

# %%
#5874
# regra :seed  /10 * 3/2

import numpy as np
np.random.seed(5874)
dados_usaveis.sample(n=7)
# Out:
#                          2007/Ago    2007/Set     2007/Out     2007/Nov  \
# Unidade da Federação
# 25 Paraíba               97352.78   368130.43   1002088.64   2149873.40
# 24 Rio Grande do Norte  134605.36   272088.08    684678.30   1695824.89
# 28 Sergipe               27453.63    78565.19    122952.94    775705.52
# 26 Pernambuco           400640.85  1088340.42   2973553.48   6699828.82
# 41 Paraná               554800.22  1431708.01   4630402.44  11120030.79
# 15 Pará                 181159.29   433414.74   1893197.50   5105406.44
# 31 Minas Gerais         971394.37  2861781.50  10018011.35  21730281.63
#
#                            2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 25 Paraíba               5448177.36  1.659900e+07  10871589.62  12348758.14
# 24 Rio Grande do Norte   4730811.68  1.176390e+07   9110108.87  10126626.54
# 28 Sergipe               2765495.63  5.439986e+06   4636850.76   5017838.07
# ...

# %%
dados_usaveis.sample(n=7).T.plot(figsize=(12,6))
# Out:
# <Axes: >

# %%
dados_usaveis["Total"] = dados_usaveis.sum(axis=1)
dados_usaveis.head()
# Out:
# <ipython-input-192-5184b59d875f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_usaveis["Total"] = dados_usaveis.sum(axis=1)
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 11 Rondônia             4209.37   16397.03   133645.19   346912.84
# 12 Acre                10470.07   14001.71    86200.85   301323.68
# 13 Amazonas            35752.72   45570.64   416012.30  2020381.79
# 14 Roraima              4785.91   11858.63    43852.67   369328.51
# 15 Pará               181159.29  433414.74  1893197.50  5105406.44
#
#                          2007/Dez     2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# ...

# %% [markdown]
# **Challenge **
#
# Ordenar datafram para que a primeira linha tenha o maior gasto, ultima, o menor
# gasto.
#
# Adicionar uma coluna com regiao
#
# Adicione seu estado na lista de 7 estados

# %%
dados_usaveis.head()
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 11 Rondônia             4209.37   16397.03   133645.19   346912.84
# 12 Acre                10470.07   14001.71    86200.85   301323.68
# 13 Amazonas            35752.72   45570.64   416012.30  2020381.79
# 14 Roraima              4785.91   11858.63    43852.67   369328.51
# 15 Pará               181159.29  433414.74  1893197.50  5105406.44
#
#                          2007/Dez     2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 11 Rondônia             711758.31   1829559.71   1940792.63   1955721.68
# 12 Acre                 769612.36   1731744.62   1743978.66   2057439.02
# 13 Amazonas            5949408.99  11419210.08   7934652.10   8641517.13
# 14 Roraima              470676.43    808448.39    771687.83    876091.18
# 15 Pará               13162823.43  21762104.16  20126081.01  22149375.82
#
# ...

# %%
ordenado_por_total = dados_usaveis.sort_values("Total", ascending = False)
ordenado_por_total.drop("Total",axis=1,inplace=True)
ordenado_por_total.head()
# Out:
#                         2007/Ago    2007/Set     2007/Out     2007/Nov  \
# Unidade da Federação
# 35 São Paulo          1665349.90  4434168.64  14577395.84  35032259.98
# 31 Minas Gerais        971394.37  2861781.50  10018011.35  21730281.63
# 41 Paraná              554800.22  1431708.01   4630402.44  11120030.79
# 43 Rio Grande do Sul  1049252.33  3182913.14   8571312.11  16592432.80
# 33 Rio de Janeiro      469469.34   921646.57   2994664.57   7250528.08
#
#                          2007/Dez      2008/Jan      2008/Fev      2008/Mar  \
# Unidade da Federação
# 35 São Paulo          76668547.41  1.108060e+09  1.736103e+08  1.709097e+08
# 31 Minas Gerais       43429517.54  2.069390e+08  7.030109e+07  7.911901e+07
# 41 Paraná             28790722.87  5.808133e+07  4.885505e+07  5.561179e+07
# 43 Rio Grande do Sul  30134255.70  5.106461e+07  4.589770e+07  5.292870e+07
# 33 Rio de Janeiro     13627123.27  2.534380e+08  4.412816e+07  4.293377e+07
#
# ...

# %%
ordenado_por_total.head(5).T.plot(figsize=(12,6))
# Out:
# <Axes: >

# %%
#Adicionar seu estado ao 5!

# %%
colunas_interessadas = ordenado_por_total.columns[6:]
colunas_interessadas
# Out:
# Index(['2008/Fev', '2008/Mar', '2008/Abr', '2008/Mai', '2008/Jun', '2008/Jul',
#        '2008/Ago', '2008/Set', '2008/Out', '2008/Nov',
#        ...
#        '2023/Set', '2023/Out', '2023/Nov', '2023/Dez', '2024/Jan', '2024/Fev',
#        '2024/Mar', '2024/Abr', '2024/Mai', '2024/Jun'],
#       dtype='object', length=197)

# %%
ordenado_por_total = ordenado_por_total[colunas_interessadas]
ordenado_por_total.head(5).T.plot(figsize=(12,6))
# Out:
# <Axes: >

# %%
#Adicionar seu estado
#Deixar o grafico mais refinado
#sort_index
